# %%
# configura caminho padrão
from utils.init_project import init_project
init_project()
# Out:
# ✅ Projeto inicializado! Raiz: h:\Portifolios_e_anotacoes_Jackson\PORTIFÓLIOS\america_ecommerce\notebook\01_extract
# WindowsPath('h:/Portifolios_e_anotacoes_Jackson/PORTIFÓLIOS/america_ecommerce/notebook/01_extract')

# %%
# importa pacotes/funções
from data_ingestion.kaggle_ingestion import download_from_kaggle
# Out:
# ✅ Projeto inicializado! Raiz: H:\Portifolios_e_anotacoes_Jackson\PORTIFÓLIOS\ecommerce

# %% [markdown]
# # Ingestão de Dados

# %%
input_path = "mervemenekse/ecommerce-dataset"
df = download_from_kaggle(input_path, sep=',')
# Out:
# 📥 Baixando dataset 'mervemenekse/ecommerce-dataset' do Kaggle...
# ...
# ✅ Arquivo copiado para: h:\Portifolios_e_anotacoes_Jackson\PORTIFÓLIOS\ecommerce\data\raw\e_commerce_dataset.csv
